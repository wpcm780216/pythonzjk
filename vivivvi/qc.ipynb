# %%
import re
import os

# %%
import re 

f1 = open("D:\\wpcmpython\\2.txt","r",encoding="utf-8")
#line = f1.readline()
#data = f1.readlines() 
str1 = f1.read()
#print(data)

f = open("D:\\wpcmpython\\abc.txt","r",encoding="utf-8")
#line = f.readline()

str2 = f.read()
#print(str)

#str = f.read()
re.findall(r"server: (\S+),", str2,re.M)
#re.findall(r"^server：(\S+),", str2, re.M)
# Out:
# ['ss-01.ssrsub.one',
#  'ss-02.ssrsub.one',
#  'ss-03.ssrsub.one',
#  'ss-04.ssrsub.one',
#  'ss-05.ssrsub.one',
#  'ss-06.ssrsub.one',
#  'ss-07.ssrsub.one',
#  'ss-08.ssrsub.one',
#  'ss-09.ssrsub.one',
#  'ss-10.ssrsub.one',
#  '66.115.147.79',
#  '185.2.100.166',
#  '185.44.76.188',
#  '185.141.206.186',
#  '5.226.139.225',
#  '89.238.130.251',
#  '185.44.76.188',
#  '103.156.50.91',
#  '103.156.51.2',
#  '66.115.175.40',
#  '207.244.67.149',
#  '66.115.182.72',
#  '212.102.44.81',
#  '104.200.131.233',
#  '207.244.67.149',
#  '207.244.84.40',
#  '107.181.166.55',
#  '143.244.60.162',
#  '98.142.220.37',
#  '45.43.14.75',
#  '212.102.44.66',
#  '104.200.131.165',
#  '184.170.250.72',
#  '173.237.207.30',
#  '184.170.250.154',
#  '185.124.240.153',
#  '195.181.171.241',
#  '198.147.22.87',
#  '185.242.5.155',
#  '212.102.44.98',
#  '45.43.14.75',
#  '66.115.175.40',
#  '84.17.35.78',
#  '199.217.107.25',
#  '207.244.67.149',
#  '74.119.146.131',
#  '199.10.64.165',
# ...

# %%
print(str)
# Out:
# <_io.TextIOWrapper name='d:/wpcmpython/2.txt' mode='r' encoding='gbk'>
